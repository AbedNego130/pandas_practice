# %% [markdown]
# # Pandas: INPUTS OUTPUTS
# En este cuaderno se pretende trabajar con distintos formatos de archivo, tanto para lectura como para escritura.

# %% [markdown]
# ## Importación de Pandas y archivo CSV

# %%
import pandas as pd

# %%
superstore_data = pd.read_csv('superstore_data.csv')

# %%
superstore_data.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
superstore_data_second_format = pd.read_csv('superstore_data_punto_coma.csv', sep=';')

# %%
superstore_data_second_format.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %% [markdown]
# ## Parametros de importacion de datos CSV
# nrows = numero de filas que se quiere leer
#
# usecols = indica las columnas que se quieren utilizar

# %%
superstore_data_5_rows = pd.read_csv('superstore_data.csv', nrows=5)

# %%
superstore_data_5_rows
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
selected_superstore_data = pd.read_csv('superstore_data.csv', usecols=['Id', 'Year_Birth', 'Income'])
# Alternativa: se puede usar el numero de la columna en lugar de usar el nombre
# selected_superstore_data = pd.read_csv('superstore_data.csv', usecols=[0, 1, 4])

# %%
selected_superstore_data
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## Guardado de archivo CSV

# %%
selected_superstore_data.to_csv('selected_superstore_data.csv', index=False)

# %%
selected_superstore_data_confirmation = pd.read_csv('selected_superstore_data.csv')

# %%
selected_superstore_data_confirmation
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### Ejercicio
# Leer archivo csv

# %%
hospital_data = pd.read_csv('datos_sus.csv', sep=';', encoding='ISO-8859-1', header=3,engine='python', skipfooter=9)
hospital_data
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ## Importación de archivo Excel

# %%
CO2_emissions = pd.read_excel('emisiones_CO2.xlsx')
CO2_emissions.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
pd.ExcelFile('emisiones_CO2.xlsx').sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
percapita_emissions = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_percapita')

# %%
percapita_emissions.sample(10)
# Out:
#                                  País ISO 3166-1 alpha-3   Año       Total  \
# 29511  Incendios Petroleros En Kuwait                NaN  1885         NaN
# 10783                       Porcelana                CHN  1925     95655.0
# 2584                          Armenia                ARM  1886         NaN
# 18757                       Finlandia                FIN  2011  10511401.0
# 994                           Andorra                AND  1928         NaN
# 7762        Islas Vírgenes Británicas                VGB  1896         NaN
# 41679     Islas Del Pacífico (Palaos)                NaN  1813         NaN
# 53922                         Surinam                SUR  1816         NaN
# 34239                        Maldivas                MDV  1989    571615.0
# 48659  Feel Marthes (Parte Holandesa)                SXM  1993  18193662.0
#
#           Carbón      Aceite        Gas   Cemento    Quema     Otros
# 29511        NaN         NaN        NaN       NaN      NaN       NaN
# ...

# %%
sources_emissions = pd.read_excel('emisiones_CO2.xlsx', sheet_name='fuentes')

# %%
sources_emissions.sample(10)
# Out:
#                                País ISO 3166-1 alpha-3   Año   Total  Carbón  \
# 41301  Territorio Palestino Ocupado                PSE  1979  [NONE]  [NONE]
# 4980                    Bielorrusia                BLR  1834  [NONE]  [NONE]
# 40857                       Noruega                NOR  1807  [NONE]  [NONE]
# 18515                     Finlandia                FIN  1769  [NONE]  [NONE]
# 23567                  Guinea-Bisáu                GNB  1925  [NONE]  [NONE]
# 2789                          Aruba                ABW  1819  [NONE]  [NONE]
# 57810                  Turkmenistán                TKM  1896  [NONE]  [NONE]
# 15787                       Ecuador                ECU  1761  [NONE]  [NONE]
# 14112               República Checa                CZE  1990   NGHGI   NGHGI
# 55769                     Tailandia                THA  1759  [NONE]  [NONE]
#
#        Aceite     Gas        Cemento   Quema   Otros               Per Capita
# ...

# %%
selected_emissions_data = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_percapita', usecols='A:D')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 selected_emissions_data = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_percapita', usecols='A:D')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
selected_emissions_data
# Out:
#              País ISO 3166-1 alpha-3   Año      Total
# 0      Afganistán                AFG  1750        NaN
# 1      Afganistán                AFG  1751        NaN
# 2      Afganistán                AFG  1752        NaN
# 3      Afganistán                AFG  1753        NaN
# 4      Afganistán                AFG  1754        NaN
# ...           ...                ...   ...        ...
# 63099      Global                WLD  2017  4749682.0
# 63100      Global                WLD  2018  4792753.0
# 63101      Global                WLD  2019  4775633.0
# 63102      Global                WLD  2020  4497423.0
# 63103      Global                WLD  2021  4693699.0
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## Escritura de archivo Excel

# %%
selected_emissions_data.to_excel('selected_emissions_data.xlsx', index=False)

# %% [markdown]
# ## Lectura de archivos JSON

# %%
patients = pd.read_json('pacientes.json')

# %%
patients
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# ### Lectura de datos con estructura anidada en JSON

# %%
patients_2 = pd.read_json('pacientes_2.json')

# %%
patients_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# Se normalizan los datos anidados dentro del json

# %%
normalized_patients = pd.json_normalize(patients_2['Pacientes'])

# %%
normalized_patients
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
# normalized_patients.to_json('normalized_patients.json')

# %% [markdown]
# ### Obteniendo datos JSON de una API

# %%
import requests
import json

datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')
datos_frutas_json = datos_frutas.json()

# %%
normalized_fruit_data = pd.json_normalize(datos_frutas_json)
normalized_fruit_data
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %% [markdown]
# ## Importacion de archivos .html

# %%
movies_general_data = pd.read_html('https://es.wikipedia.org/wiki/Anexo:AFI%27s_100_a%C3%B1os..._100_pel%C3%ADculas', )
movies_general_data
# Out:
# [    Puesto               Título original  \
#  0        1                  Citizen Kane
#  1        2                    Casablanca
#  2        3                 The Godfather
#  3        4            Gone with the wind
#  4        5            Lawrence of Arabia
#  ..     ...                           ...
#  95      96                 The Searchers
#  96      97              Bringing Up Baby
#  97      98                    Unforgiven
#  98      99  Guess Who's Coming to Dinner
#  99     100           Yankee Doodle Dandy
#
#                                   Título(s) en español  Año de lanzamiento  \
#  0     El ciudadano (AR, UY) / Ciudadano Kane (ES, HA)                1941
#  1                                          Casablanca                1942
#  2                                          El padrino                1972
#  3                           Lo que el viento se llevó                1939
#  4                                  Lawrence de Arabia                1962
# ...

# %%
movies_data = movies_general_data[0]
movies_data
# Out:
#     Puesto               Título original  \
# 0        1                  Citizen Kane
# 1        2                    Casablanca
# 2        3                 The Godfather
# 3        4            Gone with the wind
# 4        5            Lawrence of Arabia
# ..     ...                           ...
# 95      96                 The Searchers
# 96      97              Bringing Up Baby
# 97      98                    Unforgiven
# 98      99  Guess Who's Coming to Dinner
# 99     100           Yankee Doodle Dandy
#
#                                  Título(s) en español  Año de lanzamiento  \
# 0     El ciudadano (AR, UY) / Ciudadano Kane (ES, HA)                1941
# 1                                          Casablanca                1942
# 2                                          El padrino                1972
# 3                           Lo que el viento se llevó                1939
# 4                                  Lawrence de Arabia                1962
# ...

# %% [markdown]
# ## Exportacion de archivos HTML

# %%
# movies_data.to_html('movies_data.html', index=False)

# %% [markdown]
# ## Importacion de archivos XML

# %%
top_1000_movies_imdb = pd.read_xml('imdb_top_1000.xml')

# %%
top_1000_movies_imdb.head(10)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5      5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6      6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7      7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8      8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9      9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# ...

# %%
# top_1000_movies_imdb.to_xml('peliculas_imdb')

# %%
countries_general_data = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')[0]

# %% [markdown]
# ## Importacion y manupulacion de bases de datos
# Esta seccion se llevo a cabo con una libreta de colab por el uso del SQLite integrado en colab
